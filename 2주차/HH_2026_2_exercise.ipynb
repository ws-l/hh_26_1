# %% [markdown]
# ## 1. CNC Virtual Data set _v2의 폴더 내 파일들을 읽어서 하나의 데이터프레임으로 만드세요
#
# ## 2. 1의 데이터에 대해 전처리(imputing, scaling, ohe)를 적용하고 X_train, X_test, y_train, y_test를 만드는 파이프라인을 만드세요
# - y변수: Matching Process,  -X변수: 나머지
#
# ## 3.2의 파이프라인을 pkl 파일로 만들어보세요.
#
# ## 4. 2의 데이터를 제공하는 API를 만들어보세요.
#  - y변수: y, X: 나머지
#
# ## 5. 1~3 내용들을 현재 노트에서 작업하시고 결과가 보여지도록 하세요. 4의 경우에는, fastapi용으로 사용하는 py 파일을 만드세요. ipynb와 py 파일을 사번.zip으로 압축 후 LMS에 제출해주세요.
