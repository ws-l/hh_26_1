# %% [markdown]
# ## 3일차 실습
# 0. data.csv를 이용해서 데이터를 제공하는 API 구현
#
# 1. streamlit에서, API로 부터 데이터 수집하여 api_data 폴더에 csv를 생성하는 기능
#     - 파일 생성 시 현재 연월일시분초를 파일명에 반영
#     - from datetime import datetime
#     - datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
#
# 2. streamlit에서, api_data 폴더 내 csv를 읽어서 전처리 후 working directory에 하나의 csv 생성하는 기능
#
# 3. csv 파일 업로드 후 데이터프레임 생성하는 기능(세션으로 저장)
#     - 파이프 적용
#
# 4. 업로드 파일 EDA
#
# 5. 1과 2의 데이터를 DB 테이블에 추가하는 기능: 선호하는 DB로 구현
#
# 6. DB내 테이블 조회하는 기능
#
# 7. 주성분분석 후 출력 및 EDA 하는 기능
#
# #### 위의 내용 중 1은 별도의 아나콘다프롬프트에서 fastapi로 실행, 2,3,4,5,6 7은 별도의 아나콘다 프롬프트에서 streamlit으로 작동하도록 작성하신 후, 각 코드는 아래 코드셀에 붙여넣어주세요.  ipynb 파일과 덕디비 파일, 파이프라인pkl을 사번.zip 으로 압축하여 LMS에 다음주까지 제출해주세요

# %%
#api용 파이썬 코드

# %%
#streamlit용 파이썬 코드
